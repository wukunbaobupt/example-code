# %% [markdown]
# # 基于DeepST模型的预测算法

# %%
from keras import layers, Model
import numpy as np
import matplotlib.pyplot as plt
import DataPreProcess
import BuildModel
import TrainModel
import Visualization
import tensorflow
import warnings
from tensorflow.keras import optimizers

from tensorflow.keras.callbacks import Callback
warnings.filterwarnings("ignore")
print(tensorflow.__version__)

# 数据导入
# 定义数据的位置
# 2013-11、2013-12是米兰市100*100网络中心的20*20的网络数据
# 2013-11-fusion、2013-12-fusion是将100*100网络聚合成20*20网络之后的数据
total_data_path = './Data/total.vocab'
data_11 = './Data/2013-11-fusion.vocab'
data_12 = './Data/2013-12-fusion.vocab'
max_min_path = './Data/loc_max_mix.vocab'
# Out:
# 2.6.0

# %%
# 处理缺失值
data_without_missing_value = DataPreProcess.ProcessMissingValue(data_11, data_12, city_amount=400, judge_num=7)

# 处理异常值
data_without_abnormal_value = DataPreProcess.ProcessAbnormalValue(data_without_missing_value, city_amount=400, judge_week_num=8, judge_day_num=30)

# 归一化数据
total_data = DataPreProcess.DataNormalization(data_without_abnormal_value, max_min_path, city_amount=400)

# 数据保存
DataPreProcess.SavePreProcessData(total_data, total_data_path)
# Out:
# There are 122 missing datas
# There are 3364 abnormal num
# update: ./Data/loc_max_mix.vocab
# update ./Data/total.vocab
# success to save PreProcess data!

# %%
# 超参数
OPTIMIZER = optimizers.Adam(lr=5e-5)
LOSS = tensorflow.keras.losses.Huber()
BATCH_SIZE = 32
EPOCHS = 100

tensorflow.random.set_seed(47)
np.random.seed(47)

# 设置输入数据的格式，closeness、period、trend分别对应人工特征工程下时间维度的特征抽取后，准备放入模型的数据格式
closeness = layers.Input(shape=(20, 20, 3), name='closeness')
period = layers.Input(shape=(20, 20, 3), name='period')
trend = layers.Input(shape=(20, 20, 1), name='trend')
convlstmall = layers.Input(shape=(20,20, ),name='convlstmall')  #convLSTM的完整输入数据的格式
#数据类型是空间栅格，实例和格式都是以Matrics存储栅格数据 -choice A

# 数据集处理
# 获取预处理后的数据
train_data, test_data = TrainModel.MakeDataset(total_data_path)

# 获取训练数据
c_train = train_data[:, :, :, 0:3]
p_train = train_data[:, :, :, 3:6]
t_train = train_data[:, :, :, 6:7]
train_label = train_data[:, :, :, -1]
train_label = np.reshape(train_label, [train_data.shape[0], 400])

# 获取测试的数据
c_test = test_data[:, :, :, 0:3]
p_test = test_data[:, :, :, 3:6]
t_test = test_data[:, :, :, 6:7]
test_label = test_data[:, :, :, -1]
test_label = np.reshape(test_label, [test_data.shape[0], 400])
DataPreProcess.SaveLabelData(test_label, './Data/labels.vocab')
STEPS_PER_EPOCH = int(train_data.shape[0] // BATCH_SIZE)
# Out:
# (60, 400, 24)
# update ./Data/labels.vocab
# success to save PreProcess data!

# %%
# 1 MiniDeepST
# 1.1 mini-DeepST模型构建
MiniDeepST_output = BuildModel.MiniDeepST(closeness, period, trend, filters=64, kernel_size=(3,3), activation='relu', use_bias=True)
MiniDeepST = Model(inputs=[closeness, period, trend], outputs=MiniDeepST_output)
MiniDeepST.compile(optimizer=OPTIMIZER,loss=LOSS,metrics=None)
# 去掉下面一句statement的注释可以显示整个模型结构
MiniDeepST.summary()

# 1.2 训练和保存模型
print('-> Start to train MiniDeepST model!')

MiniDeepST_history = MiniDeepST.fit_generator(generator=TrainModel.Generator([c_train, p_train, t_train], train_label,  STEPS_PER_EPOCH, BATCH_SIZE),steps_per_epoch=STEPS_PER_EPOCH, epochs=EPOCHS, verbose=1, shuffle=True)
MiniDeepST_path = './Model/MiniDeepST.h5'
MiniDeepST.save_weights(MiniDeepST_path)
print('-> Finish to save trained MiniDeepST model')

# 1.3保存预测数据
MiniDeepST_result_path = './Data/MiniDeepST_result.vocab'
MiniDeepST_predict = MiniDeepST.predict([c_test, p_test, t_test], batch_size=BATCH_SIZE ,verbose=1)
print(MiniDeepST_predict.shape)
TrainModel.WriteData(MiniDeepST_result_path, MiniDeepST_predict)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# closeness (InputLayer)          [(None, 20, 20, 3)]  0
# __________________________________________________________________________________________________
# period (InputLayer)             [(None, 20, 20, 3)]  0
# __________________________________________________________________________________________________
# trend (InputLayer)              [(None, 20, 20, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 20, 20, 64)   1792        closeness[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 20, 20, 64)   1792        period[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 20, 20, 64)   640         trend[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 20, 20, 64)   36928       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 20, 20, 64)   36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 20, 20, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 20, 20, 64)   4160        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 20, 20, 64)   4160        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 20, 20, 64)   4160        conv2d_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 20, 20, 64)   0           conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 20, 20, 64)   36928       add[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 20, 20, 1)    577         conv2d_9[0][0]
# __________________________________________________________________________________________________
# output (Flatten)                (None, 400)          0           conv2d_10[0][0]
# ==================================================================================================
# Total params: 164,993
# Trainable params: 164,993
# Non-trainable params: 0
# __________________________________________________________________________________________________
# -> Start to train MiniDeepST model!
# Epoch 1/100
# 22/22 [==============================] - 16s 15ms/step - loss: 0.0155
# Epoch 2/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 3/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0060
# Epoch 4/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0047
# Epoch 5/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0039
# Epoch 6/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0035
# Epoch 7/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 8/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 9/100
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0027
# Epoch 10/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 11/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 12/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0025
# Epoch 13/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 14/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0024
# Epoch 15/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0023
# Epoch 16/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0023
# Epoch 17/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 18/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 19/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0022
# Epoch 20/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 21/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 22/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 23/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 24/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 25/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 26/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 27/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 28/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 29/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 30/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 31/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 32/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 33/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 34/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 35/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 36/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 37/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 38/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 39/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 40/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 41/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 42/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 43/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 44/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 45/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 46/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 47/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 48/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 49/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 50/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0019
# Epoch 51/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 52/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 53/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 54/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 55/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 56/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 57/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 58/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 59/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 60/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 61/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 62/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 63/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 64/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 65/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 66/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 67/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 68/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 69/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 70/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 71/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 72/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 73/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 74/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 75/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 76/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 77/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 78/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0018
# Epoch 79/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 80/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 81/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 82/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 83/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 84/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 85/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 86/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 87/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0017
# Epoch 88/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 89/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 90/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 91/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 92/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 93/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 94/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0017
# Epoch 95/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 96/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 97/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 98/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 99/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 100/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# -> Finish to save trained MiniDeepST model
# 6/6 [==============================] - 1s 85ms/step
# (168, 400)
# update:  ./Data/MiniDeepST_result.vocab
# Finish to save data!

# %%
# 2 MiniSTResNet模型
# 2.1 mini-DeepST模型构建
MiniSTResNet_output =BuildModel.MiniSTResNet(closeness, period, trend, filters=64, kernel_size=(3,3), activation='relu', use_bias=True)
MiniSTResNet = Model(inputs=[closeness, period, trend], outputs=MiniSTResNet_output)
MiniSTResNet.compile(optimizer=OPTIMIZER,loss=LOSS,metrics=None)
MiniSTResNet.summary()
# 去掉下面一句statement的注释可以显示整个模型结构

# 2.2 训练和保存模型
print('-> Start to train MiniSTResNet model!')
MiniSTResNet_history = MiniSTResNet.fit_generator(generator=TrainModel.Generator([c_train, p_train, t_train], train_label,  STEPS_PER_EPOCH, BATCH_SIZE),steps_per_epoch=STEPS_PER_EPOCH, epochs=EPOCHS, verbose=1, shuffle=True)
MiniSTResNet_path = './Model/MiniSTResNet.h5'
MiniSTResNet.save_weights(MiniSTResNet_path)
print('-> Finish to save MiniSTResNet model')

# 2.3保存预测数据
MiniSTResNet_result_path = './Data/MiniSTResNet_result.vocab'
MiniSTResNet_predict = MiniSTResNet.predict([c_test, p_test, t_test], batch_size=BATCH_SIZE ,verbose=1)
TrainModel.WriteData(MiniSTResNet_result_path, MiniSTResNet_predict)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# closeness (InputLayer)          [(None, 20, 20, 3)]  0
# __________________________________________________________________________________________________
# period (InputLayer)             [(None, 20, 20, 3)]  0
# __________________________________________________________________________________________________
# trend (InputLayer)              [(None, 20, 20, 1)]  0
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 20, 20, 64)   1792        closeness[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 20, 20, 64)   1792        period[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 20, 20, 64)   640         trend[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 20, 20, 64)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 20, 20, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 20, 20, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 20, 20, 64)   36928       re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 20, 20, 64)   0           conv2d_15[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 20, 20, 64)   0           conv2d_17[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 20, 20, 64)   0           conv2d_19[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 20, 20, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 20, 20, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 20, 20, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 20, 20, 64)   0           conv2d_21[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 20, 20, 64)   0           conv2d_23[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 20, 20, 64)   0           conv2d_25[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 20, 20, 64)   4160        add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 20, 20, 64)   4160        add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 20, 20, 64)   4160        add_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 20, 20, 64)   0           conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 20, 20, 1)    65          add_7[0][0]
# __________________________________________________________________________________________________
# output (Flatten)                (None, 400)          0           conv2d_29[0][0]
# ==================================================================================================
# Total params: 459,905
# Trainable params: 459,905
# Non-trainable params: 0
# __________________________________________________________________________________________________
# -> Start to train MiniSTResNet model!
# Epoch 1/100
# 22/22 [==============================] - 4s 35ms/step - loss: 0.0109
# Epoch 2/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0037
# Epoch 3/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0027
# Epoch 4/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0024
# Epoch 5/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0023
# Epoch 6/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0022
# Epoch 7/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0021
# Epoch 8/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0021
# Epoch 9/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0021
# Epoch 10/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0020
# Epoch 11/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0020
# Epoch 12/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0020
# Epoch 13/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0020
# Epoch 14/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0019
# Epoch 15/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 16/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 17/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0019
# Epoch 18/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 19/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 20/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 21/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 22/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 23/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 24/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 25/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 26/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 27/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 28/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 29/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 30/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 31/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 32/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 33/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 34/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0019
# Epoch 35/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0019
# Epoch 36/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 37/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 38/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 39/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 40/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 41/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 42/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 43/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 44/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 45/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 46/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0019
# Epoch 47/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 48/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 49/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 50/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 51/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 52/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 53/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 54/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 55/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 56/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 57/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 58/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 59/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 60/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0019
# Epoch 61/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 62/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 63/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 64/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 65/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 66/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 67/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 68/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 69/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0019
# Epoch 70/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 71/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0019
# Epoch 72/100
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0019
# Epoch 73/100
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0019
# Epoch 74/100
# 22/22 [==============================] - 1s 33ms/step - loss: 0.0019
# Epoch 75/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0019
# Epoch 76/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 77/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 78/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 79/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 80/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 81/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 82/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 83/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 84/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 85/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 86/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 87/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0018
# Epoch 88/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 89/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0018
# Epoch 90/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 91/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 92/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 93/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 94/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 95/100
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0018
# Epoch 96/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 97/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 98/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 99/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# Epoch 100/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0018
# -> Finish to save MiniSTResNet model
# 6/6 [==============================] - 1s 59ms/step
# update:  ./Data/MiniSTResNet_result.vocab
# Finish to save data!

# %%
# 3 MiniSTResNet_dropout_dropout模型
# 3.1 MiniSTResNet_dropout_dropout模型构建
MiniSTResNet_dropout_output =BuildModel.MiniSTResNet_dropout(closeness, period, trend, filters=64, kernel_size=(3,3), activation='relu', use_bias=True, dropout=0.25)
MiniSTResNet_dropout = Model(inputs=[closeness, period, trend], outputs=MiniSTResNet_dropout_output)
MiniSTResNet_dropout.compile(optimizer=OPTIMIZER,loss=LOSS,metrics=None)
MiniSTResNet_dropout.summary()
# 去掉下面一句statement的注释可以显示整个模型结构

# 3.2训练和保存模型
print('-> Start to train MiniSTResNet_dropout model!')
MiniSTResNet_dropout_history = MiniSTResNet_dropout.fit_generator(generator=TrainModel.Generator([c_train, p_train, t_train], train_label,  STEPS_PER_EPOCH, BATCH_SIZE),steps_per_epoch=STEPS_PER_EPOCH, epochs=EPOCHS, verbose=1, shuffle=True)
MiniSTResNet_dropout_path = './Model/MiniSTResNet_dropout.h5'
MiniSTResNet_dropout.save_weights(MiniSTResNet_dropout_path)
print('-> Finish to save MiniSTResNet_dropout model')

# 3.3保存预测数据
MiniSTResNet_dropout_result_path = './Data/MiniSTResNet_dropout_result.vocab'
MiniSTResNet_dropout_predict = MiniSTResNet_dropout.predict([c_test, p_test, t_test], batch_size=BATCH_SIZE ,verbose=1)
TrainModel.WriteData(MiniSTResNet_dropout_result_path, MiniSTResNet_dropout_predict)


# 模型训练完毕后，清理 TensorFlow 默认图和相关资源
tensorflow.keras.backend.clear_session()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# closeness (InputLayer)          [(None, 20, 20, 3)]  0
# __________________________________________________________________________________________________
# period (InputLayer)             [(None, 20, 20, 3)]  0
# __________________________________________________________________________________________________
# trend (InputLayer)              [(None, 20, 20, 1)]  0
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 20, 20, 64)   1792        closeness[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 20, 20, 64)   1792        period[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 20, 20, 64)   640         trend[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 20, 20, 64)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 20, 20, 64)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 20, 20, 64)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 20, 20, 64)   0           conv2d_34[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 20, 20, 64)   0           conv2d_36[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 20, 20, 64)   0           conv2d_38[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 20, 20, 64)   0           add_8[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 20, 20, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 20, 20, 64)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 20, 20, 64)   36928       re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 20, 20, 64)   36928       conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 20, 20, 64)   0           conv2d_40[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 20, 20, 64)   0           conv2d_42[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 20, 20, 64)   0           conv2d_44[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 20, 20, 64)   4160        add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 20, 20, 64)   4160        add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 20, 20, 64)   4160        add_13[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 20, 20, 64)   0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 20, 20, 64)   0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 20, 20, 64)   0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 20, 20, 64)   0           dropout[0][0]
#                                                                  dropout_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 20, 20, 1)    65          add_14[0][0]
# __________________________________________________________________________________________________
# output (Flatten)                (None, 400)          0           conv2d_48[0][0]
# ==================================================================================================
# Total params: 459,905
# Trainable params: 459,905
# Non-trainable params: 0
# __________________________________________________________________________________________________
# -> Start to train MiniSTResNet_dropout model!
# Epoch 1/100
# 22/22 [==============================] - 3s 32ms/step - loss: 0.0101
# Epoch 2/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0044
# Epoch 3/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0041
# Epoch 4/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0036
# Epoch 5/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0031
# Epoch 6/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0031
# Epoch 7/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0030
# Epoch 8/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0029
# Epoch 9/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0028
# Epoch 10/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0028
# Epoch 11/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0027
# Epoch 12/100
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0027
# Epoch 13/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0027
# Epoch 14/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0026
# Epoch 15/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0026
# Epoch 16/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0026
# Epoch 17/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0025
# Epoch 18/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0025
# Epoch 19/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0025
# Epoch 20/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0025
# Epoch 21/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0025
# Epoch 22/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0025
# Epoch 23/100
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0024
# Epoch 24/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0024
# Epoch 25/100
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0024
# Epoch 26/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 27/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 28/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 29/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 30/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 31/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 32/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 33/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 34/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 35/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 36/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0024
# Epoch 37/100
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0023
# Epoch 38/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 39/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 40/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 41/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 42/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 43/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 44/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 45/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 46/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 47/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 48/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 49/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 50/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 51/100
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0023
# Epoch 52/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 53/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 54/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 55/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 56/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 57/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 58/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 59/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 60/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 61/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 62/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 63/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 64/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 65/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 66/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 67/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 68/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 69/100
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0022
# Epoch 70/100
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0022
# Epoch 71/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 72/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 73/100
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0022
# Epoch 74/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 75/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 76/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 77/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 78/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 79/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 80/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 81/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 82/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 83/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 84/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 85/100
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0022
# Epoch 86/100
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0022
# Epoch 87/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 88/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 89/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 90/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 91/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 92/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 93/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0021
# Epoch 94/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 95/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 96/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 97/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0022
# Epoch 98/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 99/100
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0021
# Epoch 100/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0022
# -> Finish to save MiniSTResNet_dropout model
# 6/6 [==============================] - 0s 8ms/step
# Finish to save data!

# %%
# 3.1 Loss可视化
plt.figure(figsize=(10, 6))
plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示中文标签
plt.rcParams['font.serif'] = ['KaiTi']
plt.rcParams['axes.unicode_minus'] = False
plt.plot(MiniDeepST_history.history['loss'], color='r', label='MiniDeepST')
plt.plot(MiniSTResNet_history.history['loss'], color='orange', label='MiniSTResNet')
plt.plot(MiniSTResNet_dropout_history.history['loss'], color='g', label='MiniSTResNet_Dropout')
plt.title('训练损失', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.xlabel('Epoch', fontsize=20)
plt.legend()
plt.tight_layout()
plt.savefig('./results/5-5-9.svg', format='svg')
plt.show()

# %%
MiniDeepST_result_path = './Data/MiniDeepST_result.vocab'
MiniSTResNet_result_path = './Data/MiniSTResNet_result.vocab'
MiniSTResNet_dropout_result_path = './Data/MiniSTResNet_dropout_result.vocab'

max_min_path = './Data/loc_max_mix.vocab'
label_path = './Data/labels.vocab'

MiniDeepST_result = Visualization.DecodeData(MiniDeepST_result_path, max_min_path)
MiniSTResNet_result = Visualization.DecodeData(MiniSTResNet_result_path, max_min_path)
MiniSTResNet_dropout_result = Visualization.DecodeData(MiniSTResNet_dropout_result_path, max_min_path)
label = Visualization.DecodeData(label_path, max_min_path)

# 构建预测结果字典
results_dict = {'MiniDeepST': MiniDeepST_result, 'MiniSTResNet': MiniSTResNet_result, 'MiniSTResNet_Dropout': MiniSTResNet_dropout_result}

# 显示预测某区域的预测曲线和真实曲线
loc_id = 200
plt.figure(figsize=(15, 7))

# 显示中文标签
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['font.serif'] = ['KaiTi']
plt.rcParams['axes.unicode_minus'] = False
plt.plot(np.arange(len(MiniSTResNet_dropout_result[:,loc_id])),label[:,loc_id], c='b', label='真实值')
plt.plot(np.arange(len(MiniDeepST_result[:,loc_id])), MiniDeepST_result[:,loc_id], c='r', label='MiniDeepST')
plt.plot(np.arange(len(MiniSTResNet_result[:,loc_id])), MiniSTResNet_result[:,loc_id], c='orange', label='MiniSTResNet')
plt.plot(np.arange(len(MiniSTResNet_dropout_result[:,loc_id])), MiniSTResNet_dropout_result[:,loc_id], c='g', label='MiniSTResNet_Dropout')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
date = ['12月8日', '12月9日', '12月10日', '12月11日', '12月12日', '12月13日', '12月14日']
dt = list(range(len(label[:,loc_id])))
plt.xticks(range(1, len(dt), 24), date, rotation=0)
plt.legend(loc='best', fontsize=15)
plt.title("预测值、实际值分布图 ID=%d "%(loc_id), fontsize=20)
plt.xlabel('时间', fontsize=15)
plt.ylabel('流量', fontsize=15)
plt.tight_layout()
plt.savefig('./results/5-5-10.svg', format='svg')
plt.show()

# %%
# 显示热力图,预测结果的空间可视化
hour = 12
Visualization.HotMap(hour, results_dict, label)

# %%
#计算性能
MiniDeepST_RMSE =Visualization.CalculateRMSE(MiniDeepST_result[:,loc_id].reshape((-1, 1)), label[:,loc_id].reshape((-1, 1)))
MiniDeepST_MAE =Visualization.CalculateMAE(MiniDeepST_result[:,loc_id].reshape((-1, 1)), label[:,loc_id].reshape((-1, 1)))
MiniDeepST_R2_score =Visualization.CalculateR2score(MiniDeepST_result[:,loc_id].reshape((-1, 1)), label[:,loc_id].reshape((-1, 1)))

MiniSTResNet_RMSE =Visualization.CalculateRMSE(MiniSTResNet_result[:,loc_id].reshape((-1, 1)), label[:,loc_id].reshape((-1, 1)))
MiniSTResNet_MAE =Visualization.CalculateMAE(MiniSTResNet_result[:,loc_id].reshape((-1, 1)), label[:,loc_id].reshape((-1, 1)))
MiniSTResNet_R2_score =Visualization.CalculateR2score(MiniSTResNet_result[:,loc_id].reshape((-1, 1)), label[:,loc_id].reshape((-1, 1)))

MiniSTResNet_dropout_RMSE =Visualization.CalculateRMSE(MiniSTResNet_dropout_result[:,loc_id].reshape((-1, 1)), label[:,loc_id].reshape((-1, 1)))
MiniSTResNet_dropout_MAE =Visualization.CalculateMAE(MiniSTResNet_dropout_result[:,loc_id].reshape((-1, 1)), label[:,loc_id].reshape((-1, 1)))
MiniSTResNet_dropout_R2_score =Visualization.CalculateR2score(MiniSTResNet_dropout_result[:,loc_id].reshape((-1, 1)), label[:,loc_id].reshape((-1, 1)))

print('MiniDeepST   -> RMSE: %f.  MAE: %f.  R2_score: %f.' % (MiniDeepST_RMSE, MiniDeepST_MAE, MiniDeepST_R2_score))
print('MiniSTResNet -> RMSE: %f.  MAE: %f.  R2_score: %f.' % (MiniSTResNet_RMSE, MiniSTResNet_MAE, MiniSTResNet_R2_score))
print('MiniSTResNet_Dropout -> RMSE: %f.  MAE: %f.  R2_score: %f.' % (MiniSTResNet_dropout_RMSE, MiniSTResNet_dropout_MAE, MiniSTResNet_dropout_R2_score))
# Out:
# MiniDeepST   -> RMSE: 9.696181.  MAE: 6.756543.  R2_score: 0.923177.
# MiniSTResNet -> RMSE: 9.488485.  MAE: 6.786588.  R2_score: 0.926010.
# MiniSTResNet_Dropout -> RMSE: 9.092558.  MAE: 6.549122.  R2_score: 0.936358.
